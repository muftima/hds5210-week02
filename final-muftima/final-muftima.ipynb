# %% [markdown]
# # Final Exam
# The final exam is worth a total of 140 points, like the midterm.
# The final exam covers many of the topics that have been covered during the course of the entire semester
# Part 1 - Explaining your plan to solve the final (your algorithm) - 20 pts
# Part 2 - Reading from a JSON file for instructions - 20 pts
# Part 3 - Reading from an XML file for supplemental data - 30 pts
# Part 4 - Creating a function to calculate total cost - 30 pts
# Part 5 - Reading from a SQL database and merging it with other data - 40 pts

# %% [markdown]
# ## Background¶
# JSON files are often used not just to store data, but also to store configuration information for how a program should run. This way, your program doesn't have to be changed when minor configuration changes are all that need to change. Examples might include database configuration information, source database table names, date ranges for data processing, etc. The final includes a JSON file that provides important configuration information that will be used to direct the rest of your program on how to combine and process the data from an XML file and a SQL database. First, however, you'll need to read all the instructions and describe your approach / algorithm for solving the final exam.

# %%
JSON Configuration --------------------------------------\
                                                          >---> Total Cost per Claim
SQL Database: Prescription Claims ---------------\       /
                                                  >-----/
XML File: Mapping of Member Group to Admin Fee --/

# %% [markdown]
# ### Part 1 - Algorithm (20 pts)
# Before you start writing any code, spend some time to think through what you're planning to do. Explain your approach to the problem, possibly breaking down separate algorithms for each of the 4 segments below, if that seems natural to you.
# Only write 8-10 sentences. Anything longer will be too much detail.
# ...
# PUT YOUR ALGORITHM HERE
# ...

# %%
#Part 2: open file read everything into string and parse into json
#Part 3: parse file content into xml object, iterate over every child object of root of the tree, 
#initialize list if not already existing, extract relevant fields from hierarchy and name
#Part 4: get value list from key member_group in config dict, iterate over this list to get item cost from fees dict or 
#the supplied ingredient_cost and sum up to give the total cost
#Part 5: Get connectionto db, read from table 'claims' into list of dict. iterate over this list and for each dict extract parameters required to call calc_total_cost from part 4, 
#and insert this value back into this dict with key 'TOTAL COST'

# %% [markdown]
# # Part 2 - JSON for configuration (20 pts)
# For the final, you've been provided a JSON file that contains the following pieces of information:
# Database Connection Information:
# Database User Name
# Database Password
# Database Host
# Database Name
# Start Date - The start date for data to process, in the format YYYY-MM-DD
# End Date - The end date for data to process, in the format YYYY-MM-DD
# Cost Field Mapping - This is a dictionary that contains entries that describe which fields should be summed to compute an output field, total cost
# Fill in the function definition below to read in the configuration information from the specified JSON file. You'll know it works using the test code that provided in the function description.
# You can cat /final/config.json to see the contents of the entire file. Below is a sample file.

# %%
# %%bash
# cat /final/config_sample.json
# Out:
# {
# 	"Database User": "slucor",
# 	"Database Password": "S1UC0R",
# 	"Database Host": "localhost",
# 	"Database Name": "hds5210",
#
# 	"Start Date": "2016-11-01",
# 	"End Date": "2016-11-30",
#
# 	"Cost Field Mapping": {
# 		"MG001": ["ingredient_cost", "admin_fee", "rebate_amount"],
# 		"MG002": ["ingredient_cost"],
# 		"AZ001": ["incredient_cost", "admin_fee"]
# 	}
# }

# %%
# Put your code to read configuration information from whatever file is specified by "filename"
# Your function has to return an dictionary that has the same key/value pairs as in the file.
import json
def setup(filename):
    """(str) -> dict
    The function reads from the specified configuration file, in JSON format, and stores the contents
    in a Python dictionary.  That dictionary is returned to the caller, as shown in #4.
    
    >>> setup('/final/config_sample.json').get("Database User")
    'slucor'
    
    >>> setup('/final/config_sample.json').get("Cost Field Mapping")["MG001"][0]
    'ingredient_cost'
    
    >>> setup('/final/config_sample.json').get("Cost Field Mapping").get("AZ001")[1]
    'admin_fee'
    """
    with open (filename, "r") as inputFile:
        data=inputFile.read().replace('\n', '')
    return json.loads(data)
    print (setup('config_sample.json').get("Database User"))
    print(setup('config_sample.json').get("Cost Field Mapping")["00400F"][0])
    print(setup('config_sample.json').get("Cost Field Mapping").get("00670H")[1])

# %%
setup('/final/config_sample.json').get("Database User")
# Out:
# 'slucor'

# %%
setup('/final/config_sample.json').get("Cost Field Mapping")["MG001"][0]
# Out:
# 'ingredient_cost'

# %%
setup('/final/config_sample.json').get("Cost Field Mapping").get("AZ001")[1]
# Out:
# 'admin_fee'

# %%
import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=3)

# %% [markdown]
# ### Part 3 - Read data from XML (30 pts)
# The XML file in /final/fees.xml provides information about extra fees that are applied to prescription claims based on the member's group and whether or not the claim is for a mail order (90 day) or retail (30 day) prescription. The "admin_fee" is in this file and will be an important component in determining the final cost of the claims. You can see the contents of the XML file with the cat command below.
# Write a function that will read in the fee configuration information from the XML file specified, and return a Python dictionary that contains that information in the following format. Your format should match the structure below exactly, and you should not hard-code any field values like member group or mail/retail code. That is, your code should automatically work with any new groups or mail/retail codes that may be created in the future.
# {
#   'MG001': {
#     'MAIL': {'admin_fee': 0.5, 'processing_fee': 0.05},
#     'RETAIL': {'admin_fee': 0.5, 'processing_fee': 0.1}
#   }
# }
# You can cat the entire XML file if you like, below is a sample.

# %%
# Put your code into the function definition below.  You can test it using doc test.
import xml.etree.ElementTree as xml
def read_fees(filename):
    """(str)->dict
    
    >>> read_fees('/final/fees_sample.xml').get("MG001").get("RETAIL").get("admin_fee")
    0.5
    
    >>> read_fees('/final/fees_sample.xml').get("MG001").get("MAIL").get("processing_fee")
    0.05
    """
    tree = xml.parse(filename)
    root = tree.getroot()
    data = {}
    for child in root:
        if not child.attrib['member_group'] in data:
            data[child.attrib['member_group']] = {}
        data[child.attrib['member_group']][child.attrib['mail_retail']] = {}
        data[child.attrib['member_group']][child.attrib['mail_retail']]['admin_fee'] = float(child.find('admin_fee').text)
        data[child.attrib['member_group']][child.attrib['mail_retail']]['processing_fee'] = float(child.find('processing_fee').text)
    return data

# %%
read_fees('/final/fees_sample.xml').get("MG001").get("RETAIL").get("admin_fee")
# Out:
# 0.5

# %%
read_fees('/final/fees_sample.xml').get("MG001").get("MAIL").get("processing_fee")
# Out:
# 0.05

# %%
import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=5)

# %% [markdown]
# # Part 4 - Computing Total Cost based on Configuration Logic (30 pts)
# The logic for computing the total cost varies based on the member group, as specified in the configuration file, and requires a combination of data that will come from a database table (ingredient cost) and data from the fees.xml file.
# Write a function called calc_total_cost that will take the following parameters and return the resulting total cost.
# config - The Python dictionary loaded from your setup() function and the /final/config.json file
# fees - The Python dictionary loaded from your read_fees() function and the /final/fees.xml file
# member_group - The member group to use in computing total cost
# mail_retail - Either MAIL or RETAIL to specify
# ingredient_cost - The base ingredient cost amount.
# Your function will need to calculate a total cost based on the components defined for that member group in the config dictionary, and the fees specified for that member group in the fees dictionary.
# For example, if we provide inputs of:
# mail_retail="MAIL" and ingredient_cost=2.45
# and if the configuration file says the following within in:
# "00HH02": ["ingredient_cost", "processing_fee"]
# and fees file says the following within it:

# %% [markdown]
#  <fees member_group="00HH02" mail_retail="MAIL">
#     <admin_fee>0.93</admin_fee>
#     <processing_fee>1.84</processing_fee>
#   </fees>
#   <fees member_group="00HH02" mail_retail="RETAIL">
#     <admin_fee>0.22</admin_fee>
#     <processing_fee>1.01</processing_fee>
#   </fees>
# Then the total cost function should return:
# ingredient_cost + processing_fee for MAIL
# 2.45 + 1.84
# 4.29
# Note that the formula will not always be the same. Some member groups use just ingredient_cost to calculate the total cost, others use ingredient_cost, admin_fee, and still others use ingredient_cost, admin_fee, processing_fee.
# Round the answer to 2 decimal places

# %%
def calc_total_cost(config, fees, member_group, mail_retail, ingredient_cost):
    """(dict, dict, str, str, float) -> float
    This function uses a combination of information from the configuration dictionary,
    fees dictionary, member group name, mail retail identifier, and ingredient cost
    to compute a total cost.
    
    >>> c = setup('/final/config.json')
    >>> f = read_fees('/final/fees.xml')
    >>> calc_total_cost(c, f, "00400F", "MAIL", 2.11)
    2.11
    
    >>> calc_total_cost(c, f, "00460H", "RETAIL", 1.09)
    1.46
    """
    c = setup('/final/config.json')
    f = read_fees('/final/fees.xml')
    member = config.get("Cost Field Mapping")[member_group]
    mysum = 0
    for item in member:
        if item == 'ingredient_cost':
            mysum += ingredient_cost
        else:
             mysum += fees[member_group][mail_retail][item]
    return mysum

# %%
c = setup('/final/config.json')
f = read_fees('/final/fees.xml')
calc_total_cost(c, f, "00400F", "MAIL", 2.11)
# Out:
# 2.11

# %%
c = setup('/final/config.json')
f = read_fees('/final/fees.xml')
calc_total_cost(c, f, "00460H", "RETAIL", 1.09)
# Out:
# 1.4600000000000002

# %%
import doctest
doctest.testmod()
# Out:
# **********************************************************************
# File "__main__", line 12, in __main__.calc_total_cost
# Failed example:
#     calc_total_cost(c, f, "00460H", "RETAIL", 1.09)
# Expected:
#     1.46
# Got:
#     1.4600000000000002
# **********************************************************************
# 1 items had failures:
#    1 of   4 in __main__.calc_total_cost
# ***Test Failed*** 1 failures.
# TestResults(failed=1, attempted=9)

# %% [markdown]
# # Part 5 - Putting it together with data from a SQL database (40 pts)
# In this final step, you will read the raw data from a database into a dictionary and compute the total cost of each claim using the configuration you got from the JSON file and additional fees from the XML file. Simply store the computed TOTAL COST as another attribute of the dictionary you retrieved from the database.
# You don't need to write a separate function to do this, but you will need to include calls to your functions defined above earlier.
# The claims database table contains the following fields that you can use in your computations. You won't need all of them.
# rx_number
# member_group
# drug_ndc
# rx_count
# process_date
# new_refill_indicator
# brand_generic_ind
# mail_order_ind
# lob_code
# lob_desc
# pa_indicator
# benefit_plan_code
# business_unit_id
# paid_amount
# ingredient_cost
# sales_tax
# copay_amount
# You should expect to see results that look like the example below, but a list of 1000 items.

# %% [markdown]
# [{'TOTAL COST': Decimal('88.98'),
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '60505036302',
#   'ingredient_cost': Decimal('88.98000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('88.23000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1460346',
#   'sales_tax': Decimal('0.00000')},
#   ...

# %%
import pymysql.cursors

c = setup('/final/config.json')
f = read_fees('/final/fees.xml')

connection = pymysql.connect(
    host=c.get("Database Host"),
    user=c.get("Database User"),
    password=c.get("Database Password"),
    db=c.get("Database Name"),
    cursorclass=pymysql.cursors.DictCursor)

with connection.cursor() as cursor:
    cursor.execute("SELECT * FROM claims")
    data = cursor.fetchall()
    
for mydict in data:
    mydict['TOTAL COST'] = float(calc_total_cost(c, f, mydict['member_group'], mydict['mail_order_ind'],float(mydict['ingredient_cost'])))

# %%
data
# Out:
# [{'TOTAL COST': 88.98,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '60505036302',
#   'ingredient_cost': Decimal('88.98000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('88.23000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1460346',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 20.43,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '58177000104',
#   'ingredient_cost': Decimal('20.43000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('18.18000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '30567',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.65,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('6.65000'),
#   'drug_ndc': '603374021',
#   'ingredient_cost': Decimal('6.65000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.40000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '32531',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 5.68,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '172433180',
#   'ingredient_cost': Decimal('5.68000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.93000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1419963',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 8.38,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68180051703',
#   'ingredient_cost': Decimal('8.38000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('7.63000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1412993',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 2.59,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('4.09000'),
#   'drug_ndc': '378003210',
#   'ingredient_cost': Decimal('2.59000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('1.84000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1435922',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 8.53,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '245004115',
#   'ingredient_cost': Decimal('8.53000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('7.78000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1416661',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 11.47,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '60505014201',
#   'ingredient_cost': Decimal('11.47000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('9.22000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6727513',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 153.29,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('60.00000'),
#   'drug_ndc': '65597010590',
#   'ingredient_cost': Decimal('153.29000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('147.69000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6727561',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.82,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('17.32000'),
#   'drug_ndc': '61570007201',
#   'ingredient_cost': Decimal('15.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('15.07000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1358418',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.03,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '93715510',
#   'ingredient_cost': Decimal('15.03000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('14.28000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1484616',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 8.38,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68180051703',
#   'ingredient_cost': Decimal('8.38000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('7.63000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1484965',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 1.39,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.89000'),
#   'drug_ndc': '378020810',
#   'ingredient_cost': Decimal('1.39000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.64000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1409664',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 160.96,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('30.00000'),
#   'drug_ndc': '6011254',
#   'ingredient_cost': Decimal('160.96000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('157.51000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '191782',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 58.82,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '185028101',
#   'ingredient_cost': Decimal('58.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('56.57000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '32486',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 5.68,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '172433180',
#   'ingredient_cost': Decimal('5.68000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.93000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1494880',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.82,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('17.32000'),
#   'drug_ndc': '61570007201',
#   'ingredient_cost': Decimal('15.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('15.07000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1358418',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.03,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '93715510',
#   'ingredient_cost': Decimal('15.03000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('14.28000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1484616',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 8.38,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68180051703',
#   'ingredient_cost': Decimal('8.38000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('7.63000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1484965',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 409.57,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('60.00000'),
#   'drug_ndc': '6011231',
#   'ingredient_cost': Decimal('409.57000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('403.97000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '2518687',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 157.35,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('60.00000'),
#   'drug_ndc': '65597010430',
#   'ingredient_cost': Decimal('157.35000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('151.75000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '2518705',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 9.35,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '245005711',
#   'ingredient_cost': Decimal('9.35000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('8.60000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1499685',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 162.22,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('60.00000'),
#   'drug_ndc': '65597010590',
#   'ingredient_cost': Decimal('162.22000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('156.62000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '2903899',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 2.48,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('3.98000'),
#   'drug_ndc': '93310905',
#   'ingredient_cost': Decimal('2.48000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('1.73000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1460351',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 109.83,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '64764015104',
#   'ingredient_cost': Decimal('109.83000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'Y',
#   'paid_amount': Decimal('109.08000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1460364',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 58.82,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '185028101',
#   'ingredient_cost': Decimal('58.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('56.57000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '32486',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.82,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('17.32000'),
#   'drug_ndc': '61570007201',
#   'ingredient_cost': Decimal('15.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('15.07000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1358418',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.15,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '591346605',
#   'ingredient_cost': Decimal('6.15000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('5.40000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1455260',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 1.39,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.89000'),
#   'drug_ndc': '378020810',
#   'ingredient_cost': Decimal('1.39000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.64000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1409664',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 18.22,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '228263550',
#   'ingredient_cost': Decimal('18.22000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('17.47000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1459352',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 109.83,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('30.00000'),
#   'drug_ndc': '64764015104',
#   'ingredient_cost': Decimal('109.83000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('105.73000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1460364',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 34.96,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '60505019101',
#   'ingredient_cost': Decimal('34.96000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('32.71000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6727537',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 5.68,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '172433180',
#   'ingredient_cost': Decimal('5.68000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.93000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1419963',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.15,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '591346605',
#   'ingredient_cost': Decimal('6.15000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('5.40000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1455260',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 2.59,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('4.09000'),
#   'drug_ndc': '378003210',
#   'ingredient_cost': Decimal('2.59000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('1.84000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1435922',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 109.83,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('30.00000'),
#   'drug_ndc': '64764015104',
#   'ingredient_cost': Decimal('109.83000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('105.73000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1460364',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 8.53,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '245004115',
#   'ingredient_cost': Decimal('8.53000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('7.78000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1416661',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 20.43,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '58177000104',
#   'ingredient_cost': Decimal('20.43000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('18.18000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '30567',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.65,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('6.65000'),
#   'drug_ndc': '603374021',
#   'ingredient_cost': Decimal('6.65000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.40000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '32531',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.15,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '591346605',
#   'ingredient_cost': Decimal('6.15000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('5.40000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1494883',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 4.09,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '591034905',
#   'ingredient_cost': Decimal('4.09000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('3.34000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1497222',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 2.59,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('4.09000'),
#   'drug_ndc': '378003210',
#   'ingredient_cost': Decimal('2.59000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('1.84000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1435922',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 1.39,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.89000'),
#   'drug_ndc': '378020810',
#   'ingredient_cost': Decimal('1.39000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.64000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1409664',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 17.05,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '60505019001',
#   'ingredient_cost': Decimal('17.05000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('14.80000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '2518696',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 120.7,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('30.00000'),
#   'drug_ndc': '64764015104',
#   'ingredient_cost': Decimal('120.70000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('116.60000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1499684',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 75.11,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('30.00000'),
#   'drug_ndc': '6011254',
#   'ingredient_cost': Decimal('75.11000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'Y',
#   'paid_amount': Decimal('71.66000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '191782',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 1.16,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.66000'),
#   'drug_ndc': '51672128202',
#   'ingredient_cost': Decimal('1.16000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.41000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1505302',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 5.68,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '172433180',
#   'ingredient_cost': Decimal('5.68000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.93000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1494880',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.82,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('17.32000'),
#   'drug_ndc': '61570007201',
#   'ingredient_cost': Decimal('15.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('15.07000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1508700',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 1.39,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.89000'),
#   'drug_ndc': '378020810',
#   'ingredient_cost': Decimal('1.39000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.64000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1409664',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.03,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68180048003',
#   'ingredient_cost': Decimal('15.03000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('14.28000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1510256',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 9.35,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '245005711',
#   'ingredient_cost': Decimal('9.35000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('8.60000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1499685',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 10.1,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '378520877',
#   'ingredient_cost': Decimal('10.10000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('9.35000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1505303',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.82,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('17.32000'),
#   'drug_ndc': '61570007201',
#   'ingredient_cost': Decimal('15.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('15.07000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1508700',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 20.43,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '58177000104',
#   'ingredient_cost': Decimal('20.43000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('19.38000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '30567',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.65,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('6.65000'),
#   'drug_ndc': '603374021',
#   'ingredient_cost': Decimal('6.65000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('5.60000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '32531',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.03,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68180048003',
#   'ingredient_cost': Decimal('15.03000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('14.28000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1510256',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 120.7,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('30.00000'),
#   'drug_ndc': '64764015104',
#   'ingredient_cost': Decimal('120.70000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('116.60000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1499684',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 17.05,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '60505019000',
#   'ingredient_cost': Decimal('17.05000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('16.00000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '2518696',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 3.27,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '378013710',
#   'ingredient_cost': Decimal('3.27000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.22000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '209708',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 1.39,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.89000'),
#   'drug_ndc': '378020810',
#   'ingredient_cost': Decimal('1.39000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.64000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1529646',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 120.7,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('30.00000'),
#   'drug_ndc': '64764015104',
#   'ingredient_cost': Decimal('120.70000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('116.60000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1499684',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.82,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('17.32000'),
#   'drug_ndc': '61570007201',
#   'ingredient_cost': Decimal('15.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('15.07000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1508700',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.03,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68180048003',
#   'ingredient_cost': Decimal('15.03000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('14.28000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1510256',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 2.59,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('4.09000'),
#   'drug_ndc': '378003210',
#   'ingredient_cost': Decimal('2.59000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('1.84000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1522768',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.15,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '591346605',
#   'ingredient_cost': Decimal('6.15000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('5.40000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1494883',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 13.59,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68180048003',
#   'ingredient_cost': Decimal('13.59000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('12.84000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1510256',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.82,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('17.32000'),
#   'drug_ndc': '61570007201',
#   'ingredient_cost': Decimal('15.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('15.07000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1508700',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 5.68,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '172433180',
#   'ingredient_cost': Decimal('5.68000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.93000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1494880',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 120.7,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('30.00000'),
#   'drug_ndc': '64764015104',
#   'ingredient_cost': Decimal('120.70000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('116.60000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1499684',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 58.82,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '58177029304',
#   'ingredient_cost': Decimal('58.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('57.77000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '32486',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 2.59,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('4.09000'),
#   'drug_ndc': '378003210',
#   'ingredient_cost': Decimal('2.59000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('1.84000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1522768',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 1.39,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.89000'),
#   'drug_ndc': '378020810',
#   'ingredient_cost': Decimal('1.39000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.64000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1529646',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.15,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '591346605',
#   'ingredient_cost': Decimal('6.15000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('5.40000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1494883',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 120.7,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('30.00000'),
#   'drug_ndc': '64764015104',
#   'ingredient_cost': Decimal('120.70000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('116.60000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1499684',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 13.59,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68180048003',
#   'ingredient_cost': Decimal('13.59000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('12.84000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1510256',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 433.75,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('142.46000'),
#   'drug_ndc': '6011231',
#   'ingredient_cost': Decimal('433.75000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('430.65000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '2518687',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 171.95,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('171.95000'),
#   'drug_ndc': '65597010590',
#   'ingredient_cost': Decimal('171.95000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('168.85000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '2903899',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 2.59,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('4.09000'),
#   'drug_ndc': '378003210',
#   'ingredient_cost': Decimal('2.59000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('1.84000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1522768',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 55.79,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('57.94000'),
#   'drug_ndc': '65597010330',
#   'ingredient_cost': Decimal('55.79000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('54.84000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '215827',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 117.64,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('10.00000'),
#   'drug_ndc': '58177029304',
#   'ingredient_cost': Decimal('117.64000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('116.59000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6765179',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 9.81,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('9.81000'),
#   'drug_ndc': '60505251602',
#   'ingredient_cost': Decimal('9.81000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('8.76000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6882316',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 127.82,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('30.00000'),
#   'drug_ndc': '64764015104',
#   'ingredient_cost': Decimal('127.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('123.72000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1499684',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 9.35,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '245005711',
#   'ingredient_cost': Decimal('9.35000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('8.60000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1499685',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.15,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '53746046605',
#   'ingredient_cost': Decimal('6.15000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('5.40000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1566411',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 2.59,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('4.09000'),
#   'drug_ndc': '378003210',
#   'ingredient_cost': Decimal('2.59000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('1.84000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1522768',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 1.39,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.89000'),
#   'drug_ndc': '378020810',
#   'ingredient_cost': Decimal('1.39000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.64000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1563788',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 433.75,
#   'benefit_plan_code': 'PD3',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('433.75000'),
#   'drug_ndc': '6011231',
#   'ingredient_cost': Decimal('433.75000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'MAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'Y',
#   'paid_amount': Decimal('430.65000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '7649722',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 9.35,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '245005711',
#   'ingredient_cost': Decimal('9.35000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('8.60000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1577589',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 2.05,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('4.05000'),
#   'drug_ndc': '591034905',
#   'ingredient_cost': Decimal('2.05000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('3.00000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '218777',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 15.82,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('17.32000'),
#   'drug_ndc': '61570007201',
#   'ingredient_cost': Decimal('15.82000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00400F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('15.07000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1508700',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.15,
#   'benefit_plan_code': 'PZU',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '53746046605',
#   'ingredient_cost': Decimal('6.15000'),
# ...
#   'paid_amount': Decimal('0.00000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1150350',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 8.67,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '378615010',
#   'ingredient_cost': Decimal('8.23000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH17',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.48000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1150379',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 1.02,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('1.83000'),
#   'drug_ndc': '143147701',
#   'ingredient_cost': Decimal('0.58000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH17',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.00000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '272797',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 354.67,
#   'benefit_plan_code': 'PBP',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('17.74000'),
#   'drug_ndc': '186504031',
#   'ingredient_cost': Decimal('353.56000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00470B',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'Y',
#   'paid_amount': Decimal('354.81000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6821121',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 45.51,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68462023401',
#   'ingredient_cost': Decimal('45.04000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH19',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('41.29000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '631102',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 3.8600000000000003,
#   'benefit_plan_code': 'PBK',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('3.11000'),
#   'drug_ndc': '591034801',
#   'ingredient_cost': Decimal('1.86000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00440F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.00000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '788604',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 19.880000000000003,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '93227434',
#   'ingredient_cost': Decimal('19.41000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH19',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('15.66000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '637690',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 8.69,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '93812201',
#   'ingredient_cost': Decimal('8.25000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH17',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.50000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '469751',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 133.42,
#   'benefit_plan_code': 'PBP',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('6.68000'),
#   'drug_ndc': '74612390',
#   'ingredient_cost': Decimal('132.31000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00470B',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('133.56000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6818656',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 361.32,
#   'benefit_plan_code': 'PBP',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('18.07000'),
#   'drug_ndc': '24542131',
#   'ingredient_cost': Decimal('360.21000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00470B',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'Y',
#   'paid_amount': Decimal('361.46000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '4443324',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 5.449999999999999,
#   'benefit_plan_code': 'PBP',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.50000'),
#   'drug_ndc': '378075193',
#   'ingredient_cost': Decimal('4.34000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00470B',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('5.59000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6812308',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 3.3800000000000003,
#   'benefit_plan_code': 'PBL',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('0.00000'),
#   'drug_ndc': '378402801',
#   'ingredient_cost': Decimal('2.43000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00SNP1',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.00000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '8290554',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 8.43,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '60793085001',
#   'ingredient_cost': Decimal('7.99000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH17',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('4.24000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '268217',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 3.63,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('4.44000'),
#   'drug_ndc': '68180048101',
#   'ingredient_cost': Decimal('3.19000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH17',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.00000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '271983',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 28.200000000000003,
#   'benefit_plan_code': 'PBP',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.50000'),
#   'drug_ndc': '61570007301',
#   'ingredient_cost': Decimal('27.09000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00470B',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('28.34000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6821354',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 10.11,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '832108200',
#   'ingredient_cost': Decimal('9.94000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00470F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('5.00000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6014928',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 16.19,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '59762500001',
#   'ingredient_cost': Decimal('15.75000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH17',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('13.25000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6311949',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 392.58,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('42.00000'),
#   'drug_ndc': '58468013001',
#   'ingredient_cost': Decimal('391.08000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH18',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('350.33000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1186869',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 113.46,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('42.00000'),
#   'drug_ndc': '85128801',
#   'ingredient_cost': Decimal('113.02000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH17',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('73.52000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6316103',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 1.8499999999999999,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('2.66000'),
#   'drug_ndc': '63304062210',
#   'ingredient_cost': Decimal('1.41000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH17',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.00000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1153883',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 14.200000000000001,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68462036105',
#   'ingredient_cost': Decimal('12.64000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '4003',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('8.89000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '1073631',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 8.81,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '93729505',
#   'ingredient_cost': Decimal('7.63000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '2005',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('3.88000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '908103',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 5.59,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '603233832',
#   'ingredient_cost': Decimal('4.41000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '2005',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.66000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '923030',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 40.5,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '63304043701',
#   'ingredient_cost': Decimal('39.32000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '2005',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('35.57000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '918185',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 41.96,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '93753656',
#   'ingredient_cost': Decimal('40.46000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00HH18',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('36.71000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6643867',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.12,
#   'benefit_plan_code': 'PBK',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.84000'),
#   'drug_ndc': '53746046605',
#   'ingredient_cost': Decimal('4.59000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00000F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('0.00000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6658208',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 13.34,
#   'benefit_plan_code': 'PBK',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('7.00000'),
#   'drug_ndc': '16714066102',
#   'ingredient_cost': Decimal('11.81000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00000F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('6.06000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '6658220',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 6.75,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '64679093602',
#   'ingredient_cost': Decimal('6.58000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00470F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('6.33000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '5079482',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 3.84,
#   'benefit_plan_code': 'PBM',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('5.00000'),
#   'drug_ndc': '68180051703',
#   'ingredient_cost': Decimal('3.67000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00470F',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('3.42000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '5052124',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 2.58,
#   'benefit_plan_code': 'PBK',
#   'brand_generic_ind': 'GENERIC',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('3.91000'),
#   'drug_ndc': '53746025305',
#   'ingredient_cost': Decimal('2.58000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00530B',
#   'new_refill_indicator': 'NEW',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('2.81000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '772579',
#   'sales_tax': Decimal('0.00000')},
#  {'TOTAL COST': 213.66,
#   'benefit_plan_code': 'PBK',
#   'brand_generic_ind': 'BRAND',
#   'business_unit_id': 'HNCA',
#   'copay_amount': Decimal('214.91000'),
#   'drug_ndc': '62856024330',
#   'ingredient_cost': Decimal('213.66000'),
#   'lob_code': '',
#   'lob_desc': '',
#   'mail_order_ind': 'RETAIL',
#   'member_group': '00530B',
#   'new_refill_indicator': 'REFILL',
#   'pa_indicator': 'N',
#   'paid_amount': Decimal('211.61000'),
#   'process_date': '2015-01-05',
#   'rx_count': '',
#   'rx_number': '741327',
#   'sales_tax': Decimal('0.00000')}]
